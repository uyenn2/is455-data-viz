# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets

# %%
df_main = (r"C:\Users\14109\Downloads\volcano-events-2023-11-27_14-15-42_-0500 (1).csv")

# %%
df_main.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_main.columns
#
# AttributeError: 'str' object has no attribute 'columns'

# %%
df_main = pd.read_csv(r"C:\Users\14109\Downloads\volcano-events-2023-11-27_14-15-42_-0500 (1).csv")

# %%
df_main.columns
# Out:
# Index(['Search Parameters', 'Year', 'Mo', 'Dy', 'Tsu', 'Eq', 'Name',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Elevation (m)', 'Type',
#        'VEI', 'Agent', 'Deaths', 'Death Description', 'Missing',
#        'Missing Description', 'Injuries', 'Injuries Description',
#        'Damage ($Mil)', 'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Total Deaths',
#        'Total Death Description', 'Total Missing', 'Total Missing Description',
#        'Total Injuries', 'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description'],
#       dtype='object')

# %%
df = df_main[['Year', 'Mo','Dy','Name','Location','Country','Latitude','Longitude','Elevation (m)','Type','VEI']].drop(0)
df
# Out:
#        Year    Mo    Dy                       Name              Location  \
# 1   -4360.0   NaN   NaN                   Macauley           Kermadec Is
# 2   -4350.0   NaN   NaN                      Kikai             Ryukyu Is
# 3   -4050.0   NaN   NaN                     Masaya             Nicaragua
# 4   -4000.0   NaN   NaN                     Witori    New Britain-SW Pac
# 5   -3580.0   NaN   NaN                       Taal     Luzon-Philippines
# ..      ...   ...   ...                        ...                   ...
# 866  2022.0   1.0  15.0  Hunga Tonga-Hunga Ha'apai      Tonga-SW Pacific
# 867  2022.0   6.0  22.0               Popocatepetl                Mexico
# 868  2022.0  10.0   9.0                  Stromboli                 Italy
# 869  2022.0  12.0   4.0                  Stromboli                 Italy
# 870  2023.0   7.0   7.0                     Bagana  Bougainville-SW Paci
#
#               Country  Latitude  Longitude  Elevation (m)               Type  \
# ...

# %%
df.shape
# Out:
# (870, 11)

# %%
df.dtypes
# Out:
# Year             float64
# Mo               float64
# Dy               float64
# Name              object
# Location          object
# Country           object
# Latitude         float64
# Longitude        float64
# Elevation (m)    float64
# Type              object
# VEI              float64
# dtype: object

# %%
#df['Year'] = pd.to_datetime(['Year'])
df['Month'] = pd.to_datetime(['Mo'], errors='coerce')
df['Day'] = pd.to_datetime(['Dy'])
df['Volcanic explosivity index (VEI)'] = df['VEI']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 #df['Year'] = pd.to_datetime(['Year'])
# ----> 2 df['Month'] = pd.to_datetime(['Mo'], errors='coerce')
#       3 df['Day'] = pd.to_datetime(['Dy'])
#       4 df['Volcanic explosivity index (VEI)'] = df['VEI']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
# ...

# %%
df
# Out:
#        Year    Mo    Dy                       Name              Location  \
# 1   -4360.0   NaN   NaN                   Macauley           Kermadec Is
# 2   -4350.0   NaN   NaN                      Kikai             Ryukyu Is
# 3   -4050.0   NaN   NaN                     Masaya             Nicaragua
# 4   -4000.0   NaN   NaN                     Witori    New Britain-SW Pac
# 5   -3580.0   NaN   NaN                       Taal     Luzon-Philippines
# ..      ...   ...   ...                        ...                   ...
# 866  2022.0   1.0  15.0  Hunga Tonga-Hunga Ha'apai      Tonga-SW Pacific
# 867  2022.0   6.0  22.0               Popocatepetl                Mexico
# 868  2022.0  10.0   9.0                  Stromboli                 Italy
# 869  2022.0  12.0   4.0                  Stromboli                 Italy
# 870  2023.0   7.0   7.0                     Bagana  Bougainville-SW Paci
#
#               Country  Latitude  Longitude  Elevation (m)               Type  \
# ...

# %%
df2 = df['Type'].value_counts()
df2
# Out:
# Stratovolcano          557
# Complex volcano         91
# Caldera                 69
# Shield volcano          69
# Submarine volcano       22
# Subglacial volcano      15
# Pyroclastic shield      12
# Lava dome                9
# Tuff cone                4
# Fissure vent             4
# Pyroclastic cone         3
# Volcanic field           3
# Lava cone                2
# Cinder cone              2
# Compound volcano         2
# Maar                     2
# Crater rows              1
# Pumice cone              1
# Mud volcano              1
# Submarine volcanoes      1
# Name: Type, dtype: int64

# %%
df2.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df_type = df.groupby('Type')

# %%
df3 = df2.to_frame().reset_index()

# %%
df3
# Out:
#                   index  Type
# 0         Stratovolcano   557
# 1       Complex volcano    91
# 2               Caldera    69
# 3        Shield volcano    69
# 4     Submarine volcano    22
# 5    Subglacial volcano    15
# 6    Pyroclastic shield    12
# 7             Lava dome     9
# 8             Tuff cone     4
# 9          Fissure vent     4
# 10     Pyroclastic cone     3
# 11       Volcanic field     3
# 12            Lava cone     2
# 13          Cinder cone     2
# 14     Compound volcano     2
# 15                 Maar     2
# 16          Crater rows     1
# 17          Pumice cone     1
# 18          Mud volcano     1
# 19  Submarine volcanoes     1

# %%
df_type = df.groupby('Type').value_counts().to_frame().reset_index()

# %%
df_type
# Out:
#                     Type    Year    Mo    Dy              Name      Location  \
# 0                Caldera  1538.0   9.0  29.0     Campi Flegrei         Italy
# 1                Caldera  1694.0  11.0  20.0         Banda Api     Banda Sea
# 2                Caldera  1979.0   9.0   6.0            Asosan  Kyushu-Japan
# 3                Caldera  2018.0  12.0  22.0          Krakatau     Indonesia
# 4                Caldera  1996.0   9.0  30.0         Grimsvotn    Iceland-NE
# ..                   ...     ...   ...   ...               ...           ...
# 534    Submarine volcano  1839.0   2.0  12.0           Unnamed      Chile-Is
# 535  Submarine volcanoes  1923.0   3.0   2.0  Cendres, Ile des       SE Asia
# 536            Tuff cone  1982.0   4.0   4.0       Chichon, El        Mexico
# 537            Tuff cone  1982.0   3.0  29.0       Chichon, El        Mexico
# 538            Tuff cone  1982.0   5.0  27.0       Chichon, El        Mexico
#
# ...

# %%
import widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import widgets
#
# ModuleNotFoundError: No module named 'widgets'

# %%
import ipywidgets

# %%
@ipywidgets.interact(name = ['Weezer', 'Nerf Herder', 'Mustard Plug'],
                    age = (0, 100, 5),
                    message = "hi")
def print_bandname(name = "Mustard Plug", age = 10, message = "hi"):
    print(name, age, message)
# Out:
# interactive(children=(Dropdown(description='name', index=2, options=('Weezer', 'Nerf Herder', 'Mustard Plug'),…

# %%
options = df3['index']
@ipywidgets.interact (vol_op = options)
def make_pie_chart(vol_op):
    total_count = df3[df3['index'] != vol_op]['Type'].sum()
    selected_vol = df3[df3['index'] == vol_op]['Type'].values[0]
    proportions = [selected_vol, total_count]
    
    plt.figure()
    plt.pie(proportions, labels = [vol_op, total_count], autopct = '%1.1f%%', startangle = 90)
    plt.title(f'Percentages of Types')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='vol_op', options=('Stratovolcano', 'Complex volcano', 'Caldera', '…

# %%
df['Name'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['Name'].value_count()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df['Name'].value_counts().head(10)
# Out:
# Merapi       27
# Etna         25
# Semeru       24
# Mayon        19
# Asamayama    18
# Vesuvius     18
# Kelud        18
# Asosan       16
# Hekla        16
# Kilauea      15
# Name: Name, dtype: int64

# %%
df['Name'] == 'Merapi'
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# Name: Name, Length: 870, dtype: bool

# %%
df_merapi= df.loc[df['Name'] == ('Merapi')]
df_merapi
# Out:
#        Year    Mo    Dy    Name Location    Country  Latitude  Longitude  \
# 103  1587.0   NaN   NaN  Merapi     Java  Indonesia     -7.54    110.446
# 142  1672.0   8.0   4.0  Merapi     Java  Indonesia     -7.54    110.446
# 245  1822.0  12.0  27.0  Merapi     Java  Indonesia     -7.54    110.446
# 256  1832.0  12.0  25.0  Merapi     Java  Indonesia     -7.54    110.446
# 318  1872.0   4.0  15.0  Merapi     Java  Indonesia     -7.54    110.446
# 319  1872.0   4.0  17.0  Merapi     Java  Indonesia     -7.54    110.446
# 321  1872.0  11.0   3.0  Merapi     Java  Indonesia     -7.54    110.446
# 383  1902.0  12.0   NaN  Merapi     Java  Indonesia     -7.54    110.446
# 434  1920.0   7.0  25.0  Merapi     Java  Indonesia     -7.54    110.446
# 458  1930.0  12.0  18.0  Merapi     Java  Indonesia     -7.54    110.446
# 461  1932.0   2.0   NaN  Merapi     Java  Indonesia     -7.54    110.446
# 521  1953.0   3.0  23.0  Merapi     Java  Indonesia     -7.54    110.446
# ...

# %%
df_merapi.plot()
# Out:
# <Axes: >

# %%
import matplotlib.patches as patches
import matplotlib.transforms as transforms

# %%
fig, ax = plt.subplots(dpi = 150)
ax.scatter(df_merapi['Year'], df_merapi['VEI'])
ax.set_xlabel('Year')
ax.set_ylabel('VEI (Volcanic Explosivity Index)')
# Out:
# Text(0, 0.5, 'VEI (Volcanic Explosivity Index)')

# %%
fig, ax = plt.subplots(dpi = 150)
ax.scatter(df['Year'], df['VEI'])
ax.set_xlabel('Year')
ax.set_ylabel('VEI (Volcanic Explosivity Index)')
# Out:
# Text(0, 0.5, 'VEI (Volcanic Explosivity Index)')

# %%
fig, ax = plt.subplots(dpi = 150)
ax.plot(total_footage_owned.index, total_footage_owned)
ax.set_yscale("log")
ax.set_ylabel("Square Footage (cumulative)")
ax.set_xlabel("Year")
uiuc_annotation1 = patches.Rectangle(
    (1865, 0.0), 4, 1e7, fill = False
)
ax.add_patch(uiuc_annotation1)
uiuc_annotation2 = patches.Rectangle(
    (0.3, 0.0), 0.05, 1.0, fill = False,
    transform = ax.transAxes
)
ax.add_patch(uiuc_annotation2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 2
#       1 fig, ax = plt.subplots(dpi = 150)
# ----> 2 ax.plot(total_footage_owned.index, total_footage_owned)
#       3 ax.set_yscale("log")
#       4 ax.set_ylabel("Square Footage (cumulative)")
#
# NameError: name 'total_footage_owned' is not defined

# %%
df.loc[df['Name'] == ('Etna')]
# Out:
#        Year    Mo    Dy  Name Location Country  Latitude  Longitude  \
# 24   -141.0   NaN   NaN  Etna    Italy   Italy    37.748     14.999
# 56   1169.0   2.0   4.0  Etna    Italy   Italy    37.748     14.999
# 57   1169.0   2.0  11.0  Etna    Italy   Italy    37.748     14.999
# 67   1329.0   6.0  28.0  Etna    Italy   Italy    37.748     14.999
# 68   1329.0   7.0   NaN  Etna    Italy   Italy    37.748     14.999
# 86   1536.0   3.0  23.0  Etna    Italy   Italy    37.748     14.999
# 138  1669.0   3.0  11.0  Etna    Italy   Italy    37.748     14.999
# 139  1669.0   3.0  19.0  Etna    Italy   Italy    37.748     14.999
# 151  1693.0   1.0   9.0  Etna    Italy   Italy    37.748     14.999
# 255  1832.0  11.0   1.0  Etna    Italy   Italy    37.748     14.999
# 272  1843.0  11.0  17.0  Etna    Italy   Italy    37.748     14.999
# 308  1868.0   9.0   5.0  Etna    Italy   Italy    37.748     14.999
# 450  1928.0  11.0   2.0  Etna    Italy   Italy    37.748     14.999
# ...

# %%
df.loc[df['Name'] == ('Kilauea')]
# Out:
#        Year    Mo    Dy     Name     Location        Country  Latitude  \
# 216  1790.0  11.0   NaN  Kilauea  Hawaiian Is  United States    19.421
# 246  1823.0   2.0   NaN  Kilauea  Hawaiian Is  United States    19.421
# 264  1840.0   5.0  30.0  Kilauea  Hawaiian Is  United States    19.421
# 441  1924.0   5.0  10.0  Kilauea  Hawaiian Is  United States    19.421
# 604  1975.0  11.0  29.0  Kilauea  Hawaiian Is  United States    19.421
# 697  1993.0   4.0  19.0  Kilauea  Hawaiian Is  United States    19.421
# 731  1998.0   4.0  28.0  Kilauea  Hawaiian Is  United States    19.421
# 742  2000.0  11.0   3.0  Kilauea  Hawaiian Is  United States    19.421
# 779  2009.0  11.0  30.0  Kilauea  Hawaiian Is  United States    19.421
# 799  2012.0   2.0  10.0  Kilauea  Hawaiian Is  United States    19.421
# 800  2012.0   3.0   2.0  Kilauea  Hawaiian Is  United States    19.421
# 813  2014.0  11.0  10.0  Kilauea  Hawaiian Is  United States    19.421
# ...

# %%
df_country = df['Country'].value_counts().to_frame().reset_index()
df_country
# Out:
#                            index  Country
# 0                      Indonesia      198
# 1                          Japan      145
# 2                          Italy       60
# 3                        Iceland       53
# 4                  United States       49
# 5                    Philippines       48
# 6               Papua New Guinea       42
# 7                        Ecuador       25
# 8                      Guatemala       20
# 9                          Chile       20
# 10                        Russia       20
# 11                       Vanuatu       17
# 12                   New Zealand       15
# 13                        Mexico       13
# 14                      Colombia       11
# 15                 Pacific Ocean        9
# 16                         Samoa        8
# 17                        Greece        8
# 18                     Nicaragua        8
# 19                   Solomon Is.        7
# 20                    Costa Rica        7
# ...

# %%
options2 = df_country['index']
@ipywidgets.interact (country = options2)
def make_pie_chart(country):
    total_country2 = df_country[df_country['index'] != country]['Country'].sum()
    selected_country = df_country[df_country['index'] == country]['Country'].values[0]
    proportions2 = [selected_country, total_country2]
    
    plt.figure()
    plt.pie(proportions2, labels = [country, total_country2], autopct = '%1.1f%%', startangle = 90)
    plt.title(f'Percentages of Country')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='country', options=('Indonesia', 'Japan', 'Italy', 'Iceland', 'Unit…

# %%
ipywidgets.FloatSlider()
# Out:
# FloatSlider(value=0.0)

# %%
ipywidgets.FloatSlider(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatSlider(value=7.5, continuous_update=False, description='Test:', max=10.0, readout_format='.1f')

# %%
options2 = df_country['index']
@ipywidgets.interact (country = options2)
def make_bar_graphy(country):
    plt.figure()
    plt.bar(df_country['index'], df_country['Country'])
    plt.title(f'Total Vocalnoes per country')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='country', options=('Indonesia', 'Japan', 'Italy', 'Iceland', 'Unit…

# %%
df.groupby('Country')['Elevation'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df.groupby('Country')['Elevation'].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1416, in DataFrameGroupBy.__getitem__(self, key)
#    1407 if isinstance(key, tuple) and len(key) > 1:
#    1408     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1409     # valid syntax, so don't raise warning
#    1410     warnings.warn(
#    1411         "Indexing with multiple keys (implicitly converted to a tuple "
#    1412         "of keys) will be deprecated, use a list instead.",
#    1413         FutureWarning,
#    1414         stacklevel=find_stack_level(),
#    1415     )
# -> 1416 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
# ...

# %%
df
# Out:
#        Year    Mo    Dy                       Name              Location  \
# 1   -4360.0   NaN   NaN                   Macauley           Kermadec Is
# 2   -4350.0   NaN   NaN                      Kikai             Ryukyu Is
# 3   -4050.0   NaN   NaN                     Masaya             Nicaragua
# 4   -4000.0   NaN   NaN                     Witori    New Britain-SW Pac
# 5   -3580.0   NaN   NaN                       Taal     Luzon-Philippines
# ..      ...   ...   ...                        ...                   ...
# 866  2022.0   1.0  15.0  Hunga Tonga-Hunga Ha'apai      Tonga-SW Pacific
# 867  2022.0   6.0  22.0               Popocatepetl                Mexico
# 868  2022.0  10.0   9.0                  Stromboli                 Italy
# 869  2022.0  12.0   4.0                  Stromboli                 Italy
# 870  2023.0   7.0   7.0                     Bagana  Bougainville-SW Paci
#
#               Country  Latitude  Longitude  Elevation (m)               Type  \
# ...

# %%
df.groupby('Country')['Elevation (m)'].sum().sort_values()
# Out:
# Country
# Netherlands                       -370.0
# Vietnam                            -20.0
# Taiwan                               0.0
# Trinidad                           140.0
# Antarctica                         602.0
# Canada                             609.0
# Tonga                             1081.0
# St. Kitts & Nevis                 1156.0
# Guadeloupe                        1467.0
# Saudi Arabia                      1920.0
# Reunion                           2632.0
# North Korea                       2744.0
# China                             2865.0
# Greece                            2936.0
# Eritrea                           3843.0
# Solomon Is.                       4134.0
# St. Vincent & the Grenadines      4880.0
# Turkey                            5165.0
# Martinique                        5488.0
# Montserrat                        5490.0
# Pacific Ocean                     5640.0
# Ethiopia                          6914.0
# Yemen                             7068.0
# ...

# %%
df.loc[df['Country'] == ('Taiwan')]
# Out:
#        Year    Mo    Dy     Name     Location Country  Latitude  Longitude  \
# 285  1853.0  10.0  29.0  Unnamed  Taiwan-E of  Taiwan      24.0     121.83
#
#      Elevation (m)               Type  VEI
# 285            0.0  Submarine volcano  2.0

# %%
df.loc[df['Country'] == ('Vietnam')]
# Out:
#        Year   Mo   Dy              Name Location  Country  Latitude  \
# 437  1923.0  3.0  2.0  Cendres, Ile des  SE Asia  Vietnam    10.158
#
#      Longitude  Elevation (m)                 Type  VEI
# 437    109.014          -20.0  Submarine volcanoes  2.0

# %%
df.max()
# Out:
# Year                     2023.0
# Mo                         12.0
# Dy                         31.0
# Name                      Zukur
# Location               W Indies
# Country                   Yemen
# Latitude                 65.715
# Longitude                177.18
# Elevation (m)            6377.0
# Type             Volcanic field
# VEI                         7.0
# dtype: object

# %%
max_ele = df['Elevation (m)'].max()
print(max_ele)
# Out:
# 6377.0

# %%
df.loc[df['Name'] == ('Zukur')]
# Out:
#        Year   Mo    Dy   Name Location Country  Latitude  Longitude  \
# 145  1679.0  9.0  21.0  Zukur  Red Sea   Yemen     14.02      42.75
#
#      Elevation (m)            Type  VEI
# 145          624.0  Shield volcano  NaN

# %%
df.dtypes
# Out:
# Year             float64
# Mo               float64
# Dy               float64
# Name              object
# Location          object
# Country           object
# Latitude         float64
# Longitude        float64
# Elevation (m)    float64
# Type              object
# VEI              float64
# dtype: object

# %%
df.loc[df['Elevation (m)'] == 6377.0]
# Out:
#        Year   Mo    Dy      Name Location Country  Latitude  Longitude  \
# 211  1784.0  7.0   NaN  Coropuna     Peru    Peru    -15.52     -72.65
# 672  1990.0  5.0  29.0  Coropuna     Peru    Peru    -15.52     -72.65
#
#      Elevation (m)           Type  VEI
# 211         6377.0  Stratovolcano  NaN
# 672         6377.0  Stratovolcano  3.0

# %%
df_time_bc = df['Year'] < 1

# %%
df_time_bc
# Out:
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# Name: Year, Length: 870, dtype: bool

# %%
df_time_ad = df['Year'] >= 0

# %%
df_time = df.groupby('Year')['Name'].value_counts()

# %%
df_time
# Out:
# Year     Name
# -4360.0  Macauley                     1
# -4350.0  Kikai                        1
# -4050.0  Masaya                       1
# -4000.0  Witori                       1
# -3580.0  Taal                         1
#                                      ..
#  2021.0  Soufriere St. Vincent        1
#  2022.0  Stromboli                    2
#          Hunga Tonga-Hunga Ha'apai    1
#          Popocatepetl                 1
#  2023.0  Bagana                       1
# Name: Name, Length: 812, dtype: int64

# %%
df_time.plot()
# Out:
# <Axes: xlabel='Year,Name'>

# %%
df_time = df.groupby('Year').value_counts()

# %%
df_time
# Out:
# Year    Mo    Dy    Name                       Location          Country  Latitude  Longitude  Elevation (m)  Type               VEI
# 79.0    8.0   25.0  Vesuvius                   Italy             Italy     40.821    14.426    1281.0         Complex volcano    5.0    1
# 766.0   7.0   20.0  Aira                       Kyushu-Japan      Japan     31.593    130.657   1117.0         Stratovolcano      3.0    1
# 1104.0  10.0  15.0  Hekla                      Iceland-S         Iceland   63.983   -19.666    1490.0         Stratovolcano      5.0    1
# 1158.0  1.0   19.0  Hekla                      Iceland-S         Iceland   63.983   -19.666    1490.0         Stratovolcano      4.0    1
# 1206.0  12.0  4.0   Hekla                      Iceland-S         Iceland   63.983   -19.666    1490.0         Stratovolcano      2.0    1
#                                                                                                                                        ..
# ...

# %%
df_time.plot()
# Out:
# <Axes: xlabel='Year,Mo,Dy,Name,Location,Country,Latitude,Longitude,Elevation (m),Type,VEI'>

# %%
df
# Out:
#        Year    Mo    Dy                       Name              Location  \
# 1   -4360.0   NaN   NaN                   Macauley           Kermadec Is
# 2   -4350.0   NaN   NaN                      Kikai             Ryukyu Is
# 3   -4050.0   NaN   NaN                     Masaya             Nicaragua
# 4   -4000.0   NaN   NaN                     Witori    New Britain-SW Pac
# 5   -3580.0   NaN   NaN                       Taal     Luzon-Philippines
# ..      ...   ...   ...                        ...                   ...
# 866  2022.0   1.0  15.0  Hunga Tonga-Hunga Ha'apai      Tonga-SW Pacific
# 867  2022.0   6.0  22.0               Popocatepetl                Mexico
# 868  2022.0  10.0   9.0                  Stromboli                 Italy
# 869  2022.0  12.0   4.0                  Stromboli                 Italy
# 870  2023.0   7.0   7.0                     Bagana  Bougainville-SW Paci
#
#               Country  Latitude  Longitude  Elevation (m)               Type  \
# ...

# %%
df6 = df['Year'].value_counts().head(20)

# %%
df6
# Out:
# 2018.0    15
# 2011.0    10
# 1990.0    10
# 1997.0     9
# 2010.0     9
# 1953.0     9
# 1907.0     9
# 1993.0     9
# 1981.0     8
# 2013.0     8
# 1902.0     8
# 1992.0     8
# 2006.0     8
# 2017.0     8
# 1963.0     8
# 1974.0     7
# 1996.0     7
# 1991.0     7
# 1994.0     7
# 2015.0     7
# Name: Year, dtype: int64

# %%
df6.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df_ti
